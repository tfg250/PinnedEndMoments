# %%
import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)
import csv
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
csvin = 'txdot_results.csv'
input_file = csv.DictReader(open(csvin))
RESULTS= {}
for row in input_file:
    model = row["Model"]
    RESULTS[model]={k:row[k] for k in row.keys() if k!="Model"}

print(RESULTS['TX_24_100_P01'].keys())
# Out:
# dict_keys(['girders', 'span', 'numberofdiaphragms', 'girderspacing', 'maxXreaction', 'minendmoment', 'width', 'maxendmoment', 'Y', 'mindeflection', 'minXreaction', 'numberofgirders', 'maxmoment'])

# %%
x=[float(RESULTS[inp]['span'])/float(RESULTS[inp]['width']) for inp in sorted(RESULTS.keys())]
y=[float(RESULTS[inp]['Y']) for inp in sorted(RESULTS.keys())]
z=[max(abs(float(RESULTS[inp]['maxendmoment'])),abs(float(RESULTS[inp]['minendmoment'])))/float(RESULTS[inp]['maxmoment']) for inp in sorted(RESULTS.keys())]
text = sorted(RESULTS.keys())
trace1 = go.Scatter3d(
    x=x,
    y=y,
    z=z,
    text=text,
    mode='markers',
    hoverinfo='all',
    marker=dict(
        size=5,
        color=z,                # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=0.75
    )
)
data = [trace1]
layout = go.Layout(
                    scene = dict(
                    xaxis = dict(
                        title='Deck Length/Width'),
                    yaxis = dict(
                        title='Girder + Deck Depth (in)'),
                    zaxis = dict(
                        title='End Moment / Max Moment'),),
                    width=700,
                    margin=dict(
                    r=20, b=10,
                    l=10, t=10)
                  )
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <div id="008f4edc-9dfd-4302-9257-1129e1a96f30" style="height: 525px; width: 700px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("008f4edc-9dfd-4302-9257-1129e1a96f30", [{"hoverinfo": "all", "marker": {"color": [0.02721441952886278, 0.02657079621768678, 0.025255993962832138, 0.032313954187428585, 0.031277267793247784, 0.027435795505767812, 0.02048315754922665, 0.01853937046264701, 0.02387936148077428, 0.020721618525734405, 0.01737522195452956, 0.018603538399452137, 0.016657693589324434, 0.01800553768830228, 0.015975026103489495, 0.016749988044799106, 0.2592447326856338, 0.2584515308751466, 0.272431454488638, 0.2754491452750469, 0.25346012966143355, 0.29218280217720405, 0.2939324322674241, 0.2939462872765564, 0.2968960323089113, 0.294745724708995, 0.3052875513528994, 0.3143379207252464, 0.2952077061184268, 0.33389467294168185, 0.339
# ...

# %%
x=[float(RESULTS[inp]['span'])/float(RESULTS[inp]['width']) for inp in sorted(RESULTS.keys())]
y=[float(RESULTS[inp]['Y']) for inp in sorted(RESULTS.keys())]
z=[max(abs(float(RESULTS[inp]['maxXreaction'])),abs(float(RESULTS[inp]['minXreaction']))) for inp in sorted(RESULTS.keys())]
text = sorted(RESULTS.keys())
trace1 = go.Scatter3d(
    x=x,
    y=y,
    z=z,
    text=text,
    mode='markers',
    hoverinfo='all',
    marker=dict(
        size=5,
        color=z,                # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=0.75
    )
)
data = [trace1]
layout = go.Layout(
                    scene = dict(
                    xaxis = dict(
                        title='Deck Length/Width'),
                    yaxis = dict(
                        title='Girder + Deck Depth (in)'),
                    zaxis = dict(
                        title='Longitudinal Reaction (lbs)'),),
                    width=700,
                    margin=dict(
                    r=20, b=10,
                    l=10, t=10)
                  )
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <div id="c65fd92f-806b-4150-b9d2-c8d545da1116" style="height: 525px; width: 700px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c65fd92f-806b-4150-b9d2-c8d545da1116", [{"hoverinfo": "all", "marker": {"color": [7187.863232352111, 6696.892269216457, 5935.250890776615, 8747.263168560909, 7911.78702414156, 6457.900302140195, 5434.742955295107, 4595.562578622134, 6400.293084807997, 5166.311241654169, 4352.301695316797, 4894.499844125915, 4269.69481409064, 4988.82015845312, 3989.0843925516897, 4857.696052986558, 19204.392536865, 17399.13304655524, 16402.738971947518, 15588.50407551178, 14573.901634673477, 13834.70810997, 13202.250747061393, 12529.229613424981, 21235.141074392744, 19586.096339263007, 18326.792250024933, 18145.894810035243, 17238.880382943033, 15924.717362590454, 15578.899385497814, 15409.474147343753, 20961.733808948014
# ...
